# %%
# import dependencies (libraries in python)
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt

# add citipy library
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# add requests module
# To request JSON data over the internet, we use the Requests Library in Python.
import requests

# add datetime to recast API date a datetime format
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# import config.py file for api key
from config import weather_api_key

# %%
# latitude range -90 to 90
# longitude range -180 to 180
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
# zip method combines lats & lngs into a list of pairs.
lat_lngs = zip(lats, lngs)
lat_lngs

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 700

# %%
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid={API key}
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Loop Through the List of Cities and Build the City URL
# Handle API Request Errors with try-except Blocks
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # add current_description variable
        current_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Current Description": current_description,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
    pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | kapaa
# Processing Record 3 of Set 1 | tuktoyaktuk
# Processing Record 4 of Set 1 | nouadhibou
# Processing Record 5 of Set 1 | rungata
# City not found. Skipping...
# Processing Record 6 of Set 1 | busselton
# Processing Record 7 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 8 of Set 1 | deputatskiy
# Processing Record 9 of Set 1 | luderitz
# Processing Record 10 of Set 1 | castro
# Processing Record 11 of Set 1 | anchorage
# Processing Record 12 of Set 1 | tiarei
# Processing Record 13 of Set 1 | bluff
# Processing Record 14 of Set 1 | hammerfest
# Processing Record 15 of Set 1 | hobart
# Processing Record 16 of Set 1 | atuona
# Processing Record 17 of Set 1 | tiznit
# Processing Record 18 of Set 1 | fort nelson
# Processing Record 19 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 20 of Set 1 | quatre cocos
# Processing Record 21 of Set 1 | mataura
# Processing Record 22 of Set 1 | jamestown
# Processing Record 23 of Set 1 | bethel
# Processing Record 24 of Set 1 | rio gallegos
# Processing Record 25 of Set 1 | san cristobal
# Processing Record 26 of Set 1 | manggar
# Processing Record 27 of Set 1 | east london
# Processing Record 28 of Set 1 | butaritari
# Processing Record 29 of Set 1 | san rafael
# Processing Record 30 of Set 1 | punta arenas
# Processing Record 31 of Set 1 | huarmey
# Processing Record 32 of Set 1 | sompeta
# Processing Record 33 of Set 1 | upernavik
# Processing Record 34 of Set 1 | saint-pierre
# Processing Record 35 of Set 1 | zemio
# Processing Record 36 of Set 1 | cherskiy
# Processing Record 37 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 38 of Set 1 | saint-philippe
# Processing Record 39 of Set 1 | sao joao da barra
# Processing Record 40 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 41 of Set 1 | labuhan
# Processing Record 42 of Set 1 | avarua
# Processing Record 43 of Set 1 | tautira
# Processing Record 44 of Set 1 | hilo
# Processing Record 45 of Set 1 | geraldton
# Processing Record 46 of Set 1 | mar del plata
# Processing Record 47 of Set 1 | san andres
# Processing Record 48 of Set 1 | magalia
# Processing Record 49 of Set 1 | puerto ayora
# Processing Record 50 of Set 1 | bredasdorp
# Processing Record 1 of Set 2 | sakakah
# Processing Record 2 of Set 2 | marsa matruh
# Processing Record 3 of Set 2 | kodiak
# Processing Record 4 of Set 2 | machali
# Processing Record 5 of Set 2 | thompson
# Processing Record 6 of Set 2 | ardakan
# Processing Record 7 of Set 2 | almaznyy
# Processing Record 8 of Set 2 | alta floresta
# Processing Record 9 of Set 2 | margate
# Processing Record 10 of Set 2 | hermanus
# Processing Record 11 of Set 2 | chokurdakh
# Processing Record 12 of Set 2 | beyneu
# Processing Record 13 of Set 2 | bandundu
# Processing Record 14 of Set 2 | faanui
# Processing Record 15 of Set 2 | ushuaia
# Processing Record 16 of Set 2 | pabbi
# Processing Record 17 of Set 2 | qaanaaq
# Processing Record 18 of Set 2 | celestun
# Processing Record 19 of Set 2 | padang
# Processing Record 20 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 21 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 22 of Set 2 | saint-joseph
# Processing Record 23 of Set 2 | tiksi
# Processing Record 24 of Set 2 | hanmer springs
# Processing Record 25 of Set 2 | yablonovo
# Processing Record 26 of Set 2 | vaini
# Processing Record 27 of Set 2 | pljevlja
# Processing Record 28 of Set 2 | mezen
# Processing Record 29 of Set 2 | dikson
# Processing Record 30 of Set 2 | zhangjiakou
# Processing Record 31 of Set 2 | ancud
# Processing Record 32 of Set 2 | oulainen
# Processing Record 33 of Set 2 | vostok
# Processing Record 34 of Set 2 | nikolskoye
# Processing Record 35 of Set 2 | cape town
# Processing Record 36 of Set 2 | norman wells
# Processing Record 37 of Set 2 | bababe
# City not found. Skipping...
# Processing Record 38 of Set 2 | ixtapa
# Processing Record 39 of Set 2 | arraial do cabo
# Processing Record 40 of Set 2 | kutum
# Processing Record 41 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 42 of Set 2 | bambous virieux
# Processing Record 43 of Set 2 | arica
# Processing Record 44 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 45 of Set 2 | progreso
# Processing Record 46 of Set 2 | roald
# Processing Record 47 of Set 2 | ozinki
# Processing Record 48 of Set 2 | ballina
# Processing Record 49 of Set 2 | anadyr
# Processing Record 50 of Set 2 | porto velho
# Processing Record 1 of Set 3 | flinders
# Processing Record 2 of Set 3 | porto novo
# Processing Record 3 of Set 3 | pevek
# Processing Record 4 of Set 3 | katherine
# Processing Record 5 of Set 3 | makakilo city
# Processing Record 6 of Set 3 | ozgon
# City not found. Skipping...
# Processing Record 7 of Set 3 | rumuruti
# Processing Record 8 of Set 3 | hami
# Processing Record 9 of Set 3 | camacha
# Processing Record 10 of Set 3 | caravelas
# Processing Record 11 of Set 3 | provideniya
# Processing Record 12 of Set 3 | araguaina
# Processing Record 13 of Set 3 | port alfred
# Processing Record 14 of Set 3 | ust-kuyga
# Processing Record 15 of Set 3 | victoria
# Processing Record 16 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 17 of Set 3 | narsaq
# Processing Record 18 of Set 3 | coahuayana
# Processing Record 19 of Set 3 | yenagoa
# Processing Record 20 of Set 3 | kabin buri
# Processing Record 21 of Set 3 | severo-kurilsk
# Processing Record 22 of Set 3 | khatanga
# Processing Record 23 of Set 3 | merauke
# Processing Record 24 of Set 3 | comodoro rivadavia
# Processing Record 25 of Set 3 | sri aman
# Processing Record 26 of Set 3 | laukaa
# Processing Record 27 of Set 3 | huambo
# Processing Record 28 of Set 3 | north bend
# Processing Record 29 of Set 3 | yellowknife
# Processing Record 30 of Set 3 | albany
# Processing Record 31 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 32 of Set 3 | bud
# Processing Record 33 of Set 3 | nome
# Processing Record 34 of Set 3 | provost
# Processing Record 35 of Set 3 | jackson
# Processing Record 36 of Set 3 | iskateley
# Processing Record 37 of Set 3 | georgetown
# Processing Record 38 of Set 3 | irati
# Processing Record 39 of Set 3 | new norfolk
# Processing Record 40 of Set 3 | graaff-reinet
# Processing Record 41 of Set 3 | dawei
# Processing Record 42 of Set 3 | zhigansk
# Processing Record 43 of Set 3 | natal
# Processing Record 44 of Set 3 | sept-iles
# Processing Record 45 of Set 3 | the valley
# Processing Record 46 of Set 3 | ribeira grande
# Processing Record 47 of Set 3 | lebu
# Processing Record 48 of Set 3 | lompoc
# Processing Record 49 of Set 3 | ozernovskiy
# Processing Record 50 of Set 3 | cidreira
# Processing Record 1 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 2 of Set 4 | saskylakh
# Processing Record 3 of Set 4 | pangnirtung
# Processing Record 4 of Set 4 | riviere-au-renard
# Processing Record 5 of Set 4 | atar
# Processing Record 6 of Set 4 | airai
# Processing Record 7 of Set 4 | iqaluit
# Processing Record 8 of Set 4 | taltal
# Processing Record 9 of Set 4 | lavrentiya
# Processing Record 10 of Set 4 | pilar
# Processing Record 11 of Set 4 | vardo
# Processing Record 12 of Set 4 | aklavik
# Processing Record 13 of Set 4 | viedma
# Processing Record 14 of Set 4 | fairbanks
# Processing Record 15 of Set 4 | bilibino
# Processing Record 16 of Set 4 | carnarvon
# Processing Record 17 of Set 4 | san quintin
# Processing Record 18 of Set 4 | lagoa
# Processing Record 19 of Set 4 | vitkov
# Processing Record 20 of Set 4 | tacuarembo
# Processing Record 21 of Set 4 | salalah
# Processing Record 22 of Set 4 | alyangula
# Processing Record 23 of Set 4 | lasa
# Processing Record 24 of Set 4 | big rapids
# Processing Record 25 of Set 4 | nantucket
# Processing Record 26 of Set 4 | ponta do sol
# Processing Record 27 of Set 4 | santiago del estero
# Processing Record 28 of Set 4 | saldanha
# Processing Record 29 of Set 4 | anahuac
# Processing Record 30 of Set 4 | doha
# Processing Record 31 of Set 4 | vila franca do campo
# Processing Record 32 of Set 4 | bama
# Processing Record 33 of Set 4 | longyearbyen
# Processing Record 34 of Set 4 | kalmunai
# Processing Record 35 of Set 4 | egvekinot
# Processing Record 36 of Set 4 | katsuura
# Processing Record 37 of Set 4 | jarvenpaa
# Processing Record 38 of Set 4 | campbellsville
# Processing Record 39 of Set 4 | lang son
# Processing Record 40 of Set 4 | port blair
# Processing Record 41 of Set 4 | whitehorse
# Processing Record 42 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 43 of Set 4 | kahului
# Processing Record 44 of Set 4 | valle hermoso
# Processing Record 45 of Set 4 | college
# Processing Record 46 of Set 4 | arinos
# Processing Record 47 of Set 4 | hithadhoo
# Processing Record 48 of Set 4 | vila velha
# Processing Record 49 of Set 4 | bengkulu
# Processing Record 50 of Set 4 | port hedland
# Processing Record 1 of Set 5 | ukiah
# Processing Record 2 of Set 5 | veraval
# Processing Record 3 of Set 5 | umm kaddadah
# Processing Record 4 of Set 5 | qaqortoq
# Processing Record 5 of Set 5 | bargal
# City not found. Skipping...
# Processing Record 6 of Set 5 | yanchukan
# City not found. Skipping...
# Processing Record 7 of Set 5 | zaraza
# Processing Record 8 of Set 5 | sorland
# Processing Record 9 of Set 5 | praia
# Processing Record 10 of Set 5 | sulangan
# Processing Record 11 of Set 5 | chapais
# Processing Record 12 of Set 5 | gravdal
# Processing Record 13 of Set 5 | sao jose da coroa grande
# Processing Record 14 of Set 5 | izumo
# Processing Record 15 of Set 5 | barzas
# Processing Record 16 of Set 5 | fairview
# Processing Record 17 of Set 5 | oistins
# Processing Record 18 of Set 5 | pathein
# Processing Record 19 of Set 5 | nanortalik
# Processing Record 20 of Set 5 | faya
# Processing Record 21 of Set 5 | tasiilaq
# Processing Record 22 of Set 5 | haines junction
# Processing Record 23 of Set 5 | fougamou
# Processing Record 24 of Set 5 | kedrovyy
# Processing Record 25 of Set 5 | gat
# Processing Record 26 of Set 5 | blackfoot
# Processing Record 27 of Set 5 | limbang
# Processing Record 28 of Set 5 | broome
# Processing Record 29 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 30 of Set 5 | fortuna
# Processing Record 31 of Set 5 | codrington
# Processing Record 32 of Set 5 | yanliang
# Processing Record 33 of Set 5 | toamasina
# Processing Record 34 of Set 5 | hamilton
# Processing Record 35 of Set 5 | abu dhabi
# Processing Record 36 of Set 5 | hita
# Processing Record 37 of Set 5 | yar-sale
# Processing Record 38 of Set 5 | thinadhoo
# Processing Record 39 of Set 5 | baiyin
# Processing Record 40 of Set 5 | kaitangata
# Processing Record 41 of Set 5 | iquique
# Processing Record 42 of Set 5 | vila do maio
# Processing Record 43 of Set 5 | barrow
# Processing Record 44 of Set 5 | kazalinsk
# City not found. Skipping...
# Processing Record 45 of Set 5 | leh
# Processing Record 46 of Set 5 | pitkyaranta
# Processing Record 47 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 48 of Set 5 | dagana
# Processing Record 49 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 50 of Set 5 | tabory
# Processing Record 1 of Set 6 | ahuimanu
# Processing Record 2 of Set 6 | fochville
# Processing Record 3 of Set 6 | olafsvik
# Processing Record 4 of Set 6 | flin flon
# Processing Record 5 of Set 6 | ornskoldsvik
# Processing Record 6 of Set 6 | pizarro
# Processing Record 7 of Set 6 | sanok
# Processing Record 8 of Set 6 | gizo
# Processing Record 9 of Set 6 | kasempa
# Processing Record 10 of Set 6 | kuytun
# Processing Record 11 of Set 6 | port elizabeth
# Processing Record 12 of Set 6 | guerrero negro
# Processing Record 13 of Set 6 | haukipudas
# Processing Record 14 of Set 6 | benguela
# Processing Record 15 of Set 6 | beringovskiy
# Processing Record 16 of Set 6 | tucurui
# Processing Record 17 of Set 6 | kolosovka
# Processing Record 18 of Set 6 | imeni poliny osipenko
# Processing Record 19 of Set 6 | te anau
# Processing Record 20 of Set 6 | harper
# Processing Record 21 of Set 6 | coquimbo
# Processing Record 22 of Set 6 | hastings
# Processing Record 23 of Set 6 | mahebourg
# Processing Record 24 of Set 6 | dingle
# Processing Record 25 of Set 6 | zholymbet
# Processing Record 26 of Set 6 | new ulm
# Processing Record 27 of Set 6 | orangeburg
# Processing Record 28 of Set 6 | shingu
# Processing Record 29 of Set 6 | tilichiki
# Processing Record 30 of Set 6 | sistranda
# Processing Record 31 of Set 6 | buraydah
# Processing Record 32 of Set 6 | ulladulla
# Processing Record 33 of Set 6 | tokur
# Processing Record 34 of Set 6 | wucheng
# Processing Record 35 of Set 6 | comarapa
# Processing Record 36 of Set 6 | eyl
# Processing Record 37 of Set 6 | buala
# Processing Record 38 of Set 6 | pisco
# Processing Record 39 of Set 6 | biltine
# Processing Record 40 of Set 6 | hunza
# City not found. Skipping...
# Processing Record 41 of Set 6 | bathsheba
# Processing Record 42 of Set 6 | gouyave
# Processing Record 43 of Set 6 | peniche
# Processing Record 44 of Set 6 | sergeyevka
# Processing Record 45 of Set 6 | general teran
# Processing Record 46 of Set 6 | aitape
# Processing Record 47 of Set 6 | ishigaki
# Processing Record 48 of Set 6 | humaita
# Processing Record 49 of Set 6 | kavieng
# Processing Record 50 of Set 6 | kidodi
# Processing Record 1 of Set 7 | winnemucca
# Processing Record 2 of Set 7 | bubaque
# Processing Record 3 of Set 7 | pacific grove
# Processing Record 4 of Set 7 | mount gambier
# Processing Record 5 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 6 of Set 7 | tura
# Processing Record 7 of Set 7 | bonavista
# Processing Record 8 of Set 7 | guarapari
# Processing Record 9 of Set 7 | siyabuswa
# Processing Record 10 of Set 7 | katete
# Processing Record 11 of Set 7 | half moon bay
# Processing Record 12 of Set 7 | castrillon
# Processing Record 13 of Set 7 | qasigiannguit
# Processing Record 14 of Set 7 | asau
# Processing Record 15 of Set 7 | armacao dos buzios
# City not found. Skipping...
# Processing Record 16 of Set 7 | quelimane
# Processing Record 17 of Set 7 | paita
# Processing Record 18 of Set 7 | talnakh
# Processing Record 19 of Set 7 | isla vista
# Processing Record 20 of Set 7 | souillac
# Processing Record 21 of Set 7 | changping
# Processing Record 22 of Set 7 | leningradskiy
# Processing Record 23 of Set 7 | sisimiut
# Processing Record 24 of Set 7 | poum
# Processing Record 25 of Set 7 | kaeo
# Processing Record 26 of Set 7 | oranjemund
# Processing Record 27 of Set 7 | ayan
# Processing Record 28 of Set 7 | belle fourche
# Processing Record 29 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 30 of Set 7 | baykit
# Processing Record 31 of Set 7 | temyasovo
# Processing Record 32 of Set 7 | saint george
# Processing Record 33 of Set 7 | ust-maya
# Processing Record 34 of Set 7 | goderich
# Processing Record 35 of Set 7 | beloha
# Processing Record 36 of Set 7 | sokoni
# Processing Record 37 of Set 7 | sao miguel do araguaia
# Processing Record 38 of Set 7 | iberia
# Processing Record 39 of Set 7 | carberry
# Processing Record 40 of Set 7 | black river
# Processing Record 41 of Set 7 | tuatapere
# Processing Record 42 of Set 7 | hambantota
# Processing Record 43 of Set 7 | novikovo
# Processing Record 44 of Set 7 | kuala lipis
# Processing Record 45 of Set 7 | ailigandi
# Processing Record 46 of Set 7 | manaskent
# Processing Record 47 of Set 7 | karratha
# Processing Record 48 of Set 7 | naze
# Processing Record 49 of Set 7 | olinda
# Processing Record 50 of Set 7 | yulara
# Processing Record 1 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 2 of Set 8 | jacareacanga
# Processing Record 3 of Set 8 | torbay
# Processing Record 4 of Set 8 | sao mateus
# Processing Record 5 of Set 8 | lorengau
# Processing Record 6 of Set 8 | methoni
# Processing Record 7 of Set 8 | cao bang
# Processing Record 8 of Set 8 | laguna
# Processing Record 9 of Set 8 | boa vista
# Processing Record 10 of Set 8 | sao filipe
# Processing Record 11 of Set 8 | opuwo
# Processing Record 12 of Set 8 | kruisfontein
# Processing Record 13 of Set 8 | effingham
# Processing Record 14 of Set 8 | bonthe
# Processing Record 15 of Set 8 | roma
# Processing Record 16 of Set 8 | quchan
# Processing Record 17 of Set 8 | kapit
# Processing Record 18 of Set 8 | blagoyevo
# Processing Record 19 of Set 8 | ilulissat
# Processing Record 20 of Set 8 | namatanai
# Processing Record 21 of Set 8 | chicama
# Processing Record 22 of Set 8 | urucara
# Processing Record 23 of Set 8 | garden city
# Processing Record 24 of Set 8 | katobu
# Processing Record 25 of Set 8 | nalut
# Processing Record 26 of Set 8 | cairns
# Processing Record 27 of Set 8 | kloulklubed
# Processing Record 28 of Set 8 | urumqi
# Processing Record 29 of Set 8 | hearst
# Processing Record 30 of Set 8 | iquitos
# Processing Record 31 of Set 8 | sitka
# Processing Record 32 of Set 8 | les cayes
# Processing Record 33 of Set 8 | lata
# Processing Record 34 of Set 8 | tomatlan
# Processing Record 35 of Set 8 | road town
# Processing Record 36 of Set 8 | senanga
# Processing Record 37 of Set 8 | manono
# Processing Record 38 of Set 8 | tazmalt
# Processing Record 39 of Set 8 | hinganghat
# Processing Record 40 of Set 8 | ahmadpur
# Processing Record 41 of Set 8 | longyan
# Processing Record 42 of Set 8 | beipiao
# Processing Record 43 of Set 8 | kaniama
# Processing Record 44 of Set 8 | kysyl-syr
# Processing Record 45 of Set 8 | coihaique
# Processing Record 46 of Set 8 | saint-georges
# Processing Record 47 of Set 8 | luoyang
# Processing Record 48 of Set 8 | wahran
# City not found. Skipping...
# Processing Record 49 of Set 8 | mudyuga
# City not found. Skipping...
# Processing Record 50 of Set 8 | walvis bay
# Processing Record 1 of Set 9 | kaifeng
# Processing Record 2 of Set 9 | tanout
# Processing Record 3 of Set 9 | iracoubo
# Processing Record 4 of Set 9 | turukhansk
# Processing Record 5 of Set 9 | angoche
# Processing Record 6 of Set 9 | surman
# Processing Record 7 of Set 9 | nuuk
# Processing Record 8 of Set 9 | mount isa
# Processing Record 9 of Set 9 | ulaanbaatar
# Processing Record 10 of Set 9 | chuy
# Processing Record 11 of Set 9 | la ronge
# Processing Record 12 of Set 9 | fuerte olimpo
# Processing Record 13 of Set 9 | shemysheyka
# Processing Record 14 of Set 9 | balatonszabadi
# Processing Record 15 of Set 9 | killybegs
# Processing Record 16 of Set 9 | sola
# Processing Record 17 of Set 9 | ondo
# Processing Record 18 of Set 9 | matola
# Processing Record 19 of Set 9 | safaga
# Processing Record 20 of Set 9 | krsko
# Processing Record 21 of Set 9 | mehamn
# Processing Record 22 of Set 9 | husavik
# Processing Record 23 of Set 9 | kazachinskoye
# Processing Record 24 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 25 of Set 9 | khonuu
# City not found. Skipping...
# Processing Record 26 of Set 9 | surat
# Processing Record 27 of Set 9 | liuzhou
# Processing Record 28 of Set 9 | wanning
# Processing Record 29 of Set 9 | bara
# Processing Record 30 of Set 9 | kuldur
# Processing Record 31 of Set 9 | eureka
# Processing Record 32 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 33 of Set 9 | miandrivazo
# Processing Record 34 of Set 9 | abu kamal
# Processing Record 35 of Set 9 | port-cartier
# Processing Record 36 of Set 9 | cabo san lucas
# Processing Record 37 of Set 9 | esperance
# Processing Record 38 of Set 9 | waipawa
# Processing Record 39 of Set 9 | sioux lookout
# Processing Record 40 of Set 9 | hofn
# Processing Record 41 of Set 9 | luang prabang
# Processing Record 42 of Set 9 | zhob
# Processing Record 43 of Set 9 | baishishan
# Processing Record 44 of Set 9 | vestmannaeyjar
# Processing Record 45 of Set 9 | rio grande
# Processing Record 46 of Set 9 | najran
# Processing Record 47 of Set 9 | hovd
# Processing Record 48 of Set 9 | denizli
# Processing Record 49 of Set 9 | deniliquin
# Processing Record 50 of Set 9 | chara
# Processing Record 1 of Set 10 | kyabram
# Processing Record 2 of Set 10 | sambava
# Processing Record 3 of Set 10 | morros
# Processing Record 4 of Set 10 | yarovoye
# Processing Record 5 of Set 10 | christchurch
# Processing Record 6 of Set 10 | suluq
# Processing Record 7 of Set 10 | ulagan
# Processing Record 8 of Set 10 | grand gaube
# Processing Record 9 of Set 10 | ahipara
# Processing Record 10 of Set 10 | otterup
# Processing Record 11 of Set 10 | karakose
# City not found. Skipping...
# Processing Record 12 of Set 10 | semey
# Processing Record 13 of Set 10 | bure
# Processing Record 14 of Set 10 | tanggu
# Processing Record 15 of Set 10 | igrim
# Processing Record 16 of Set 10 | pahrump
# Processing Record 17 of Set 10 | bandarbeyla
# Processing Record 18 of Set 10 | panzhihua
# Processing Record 19 of Set 10 | auki
# Processing Record 20 of Set 10 | meulaboh
# Processing Record 21 of Set 10 | chinsali
# Processing Record 22 of Set 10 | saint-pierre-des-corps
# Processing Record 23 of Set 10 | troitsko-pechorsk
# Processing Record 24 of Set 10 | bull savanna
# Processing Record 25 of Set 10 | yeletskiy
# City not found. Skipping...
# Processing Record 26 of Set 10 | baruun-urt
# Processing Record 27 of Set 10 | maracana
# Processing Record 28 of Set 10 | pozo colorado
# Processing Record 29 of Set 10 | pombas
# Processing Record 30 of Set 10 | artyom
# Processing Record 31 of Set 10 | alofi
# Processing Record 32 of Set 10 | aykhal
# Processing Record 33 of Set 10 | murgab
# Processing Record 34 of Set 10 | sabha
# Processing Record 35 of Set 10 | paso de los toros
# Processing Record 36 of Set 10 | yenangyaung
# Processing Record 37 of Set 10 | maragogi
# Processing Record 38 of Set 10 | ribeira brava
# Processing Record 39 of Set 10 | kosa
# Processing Record 40 of Set 10 | jijiga
# Processing Record 41 of Set 10 | taoudenni
# Processing Record 42 of Set 10 | brownsville
# Processing Record 43 of Set 10 | barra do garcas
# Processing Record 44 of Set 10 | ranong
# Processing Record 45 of Set 10 | akdepe
# Processing Record 46 of Set 10 | eidsvag
# Processing Record 47 of Set 10 | paka
# Processing Record 48 of Set 10 | shubarshi
# Processing Record 49 of Set 10 | nishihara
# Processing Record 50 of Set 10 | hervey bay
# Processing Record 1 of Set 11 | french harbor
# Processing Record 2 of Set 11 | emba
# Processing Record 3 of Set 11 | smidovich
# Processing Record 4 of Set 11 | saint anthony
# Processing Record 5 of Set 11 | patiya
# Processing Record 6 of Set 11 | namibe
# Processing Record 7 of Set 11 | rabo de peixe
# Processing Record 8 of Set 11 | yangambi
# Processing Record 9 of Set 11 | gonzalez
# Processing Record 10 of Set 11 | ruatoria
# City not found. Skipping...
# Processing Record 11 of Set 11 | cap malheureux
# Processing Record 12 of Set 11 | shonguy
# Processing Record 13 of Set 11 | shimoda
# Processing Record 14 of Set 11 | yellamanchili
# City not found. Skipping...
# Processing Record 15 of Set 11 | douglas
# Processing Record 16 of Set 11 | paytug
# City not found. Skipping...
# Processing Record 17 of Set 11 | nueve de julio
# Processing Record 18 of Set 11 | yumen
# Processing Record 19 of Set 11 | kropotkin
# Processing Record 20 of Set 11 | ucluelet
# Processing Record 21 of Set 11 | grand-santi
# Processing Record 22 of Set 11 | komsomolskiy
# Processing Record 23 of Set 11 | priego de cordoba
# Processing Record 24 of Set 11 | igdir
# Processing Record 25 of Set 11 | cockburn town
# Processing Record 26 of Set 11 | klyuchi
# Processing Record 27 of Set 11 | ternate
# Processing Record 28 of Set 11 | anori
# Processing Record 29 of Set 11 | russell
# Processing Record 30 of Set 11 | lebanon
# Processing Record 31 of Set 11 | maniitsoq
# Processing Record 32 of Set 11 | maningrida
# Processing Record 33 of Set 11 | westport
# Processing Record 34 of Set 11 | ambilobe
# Processing Record 35 of Set 11 | qadirpur ran
# Processing Record 36 of Set 11 | barawe
# City not found. Skipping...
# Processing Record 37 of Set 11 | ouesso
# Processing Record 38 of Set 11 | tinskoy
# Processing Record 39 of Set 11 | siwan
# Processing Record 40 of Set 11 | nurota
# Processing Record 41 of Set 11 | price
# Processing Record 42 of Set 11 | west wendover
# Processing Record 43 of Set 11 | alice springs
# Processing Record 44 of Set 11 | tongren
# Processing Record 45 of Set 11 | vestmanna
# Processing Record 46 of Set 11 | unity
# Processing Record 47 of Set 11 | samarai
# Processing Record 48 of Set 11 | vangaindrano
# Processing Record 49 of Set 11 | tambo grande
# Processing Record 50 of Set 11 | temaraia
# City not found. Skipping...
# Processing Record 1 of Set 12 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 2 of Set 12 | anar darreh
# City not found. Skipping...
# Processing Record 3 of Set 12 | grevesmuhlen
# Processing Record 4 of Set 12 | staryy biser
# City not found. Skipping...
# Processing Record 5 of Set 12 | port-gentil
# Processing Record 6 of Set 12 | kotelnich
# Processing Record 7 of Set 12 | isangel
# Processing Record 8 of Set 12 | manuk mangkaw
# Processing Record 9 of Set 12 | san patricio
# Processing Record 10 of Set 12 | sovetskaya
# Processing Record 11 of Set 12 | dali
# Processing Record 12 of Set 12 | clyde river
# Processing Record 13 of Set 12 | umea
# Processing Record 14 of Set 12 | da nang
# Processing Record 15 of Set 12 | grindavik
# Processing Record 16 of Set 12 | mahibadhoo
# Processing Record 17 of Set 12 | mazagao
# Processing Record 18 of Set 12 | paamiut
# Processing Record 19 of Set 12 | miranda
# Processing Record 20 of Set 12 | colesberg
# Processing Record 21 of Set 12 | aktau
# Processing Record 22 of Set 12 | poya
# Processing Record 23 of Set 12 | hualmay
# Processing Record 24 of Set 12 | omboue
# Processing Record 25 of Set 12 | vrede
# Processing Record 26 of Set 12 | wanaka
# Processing Record 27 of Set 12 | portobelo
# Processing Record 28 of Set 12 | yambio
# Processing Record 29 of Set 12 | mae ramat
# Processing Record 30 of Set 12 | richards bay
# Processing Record 31 of Set 12 | kushima
# Processing Record 32 of Set 12 | south river
# Processing Record 33 of Set 12 | usinsk
# Processing Record 34 of Set 12 | mulege
# Processing Record 35 of Set 12 | lingyuan
# Processing Record 36 of Set 12 | loei
# Processing Record 37 of Set 12 | puntarenas
# Processing Record 38 of Set 12 | fare
# Processing Record 39 of Set 12 | cheuskiny
# City not found. Skipping...
# Processing Record 40 of Set 12 | springbok
# Processing Record 41 of Set 12 | rudnya
# Processing Record 42 of Set 12 | biak
# Processing Record 43 of Set 12 | ugoofaaru
# Processing Record 44 of Set 12 | bazarnyy karabulak
# Processing Record 45 of Set 12 | necochea
# Processing Record 46 of Set 12 | pskov
# Processing Record 47 of Set 12 | sur
# Processing Record 48 of Set 12 | rincon
# Processing Record 49 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 50 of Set 12 | surprise
# Processing Record 1 of Set 13 | mrirt
# City not found. Skipping...
# Processing Record 2 of Set 13 | surt
# Processing Record 3 of Set 13 | tuy hoa
# Processing Record 4 of Set 13 | mormugao
# Processing Record 5 of Set 13 | vitre
# Processing Record 6 of Set 13 | aksu
# Processing Record 7 of Set 13 | royan
# Processing Record 8 of Set 13 | bairiki
# Processing Record 9 of Set 13 | staryy nadym
# Processing Record 10 of Set 13 | fenoarivo
# Processing Record 11 of Set 13 | erenhot
# Processing Record 12 of Set 13 | bontang
# Processing Record 13 of Set 13 | kachikau
# City not found. Skipping...
# Processing Record 14 of Set 13 | taga
# Processing Record 15 of Set 13 | podyuga
# Processing Record 16 of Set 13 | santa isabel
# Processing Record 17 of Set 13 | mayumba
# Processing Record 18 of Set 13 | tsentralnyy
# City not found. Skipping...
# Processing Record 19 of Set 13 | lafia
# Processing Record 20 of Set 13 | gelgaudiskis
# Processing Record 21 of Set 13 | srednekolymsk
# Processing Record 22 of Set 13 | piacabucu
# Processing Record 23 of Set 13 | liverpool
# Processing Record 24 of Set 13 | never
# Processing Record 25 of Set 13 | coos bay
# Processing Record 26 of Set 13 | lixourion
# Processing Record 27 of Set 13 | karaton
# Processing Record 28 of Set 13 | korla
# Processing Record 29 of Set 13 | gamba
# Processing Record 30 of Set 13 | dolbeau
# City not found. Skipping...
# Processing Record 31 of Set 13 | tezu
# Processing Record 32 of Set 13 | acarau
# Processing Record 33 of Set 13 | rongu
# City not found. Skipping...
# Processing Record 34 of Set 13 | domoni
# Processing Record 35 of Set 13 | vallenar
# Processing Record 36 of Set 13 | pankrushikha
# Processing Record 37 of Set 13 | birobidzhan
# Processing Record 38 of Set 13 | yining
# Processing Record 39 of Set 13 | kayes
# Processing Record 40 of Set 13 | bani
# Processing Record 41 of Set 13 | teya
# Processing Record 42 of Set 13 | hasaki
# Processing Record 43 of Set 13 | ovsyanka
# Processing Record 44 of Set 13 | soe
# Processing Record 45 of Set 13 | suhbaatar
# Processing Record 46 of Set 13 | barranca
# Processing Record 47 of Set 13 | zorritos
# Processing Record 48 of Set 13 | sapa
# Processing Record 49 of Set 13 | sobolevo
# Processing Record 50 of Set 13 | milkovo
# Processing Record 1 of Set 14 | lac du bonnet
# Processing Record 2 of Set 14 | arman
# Processing Record 3 of Set 14 | kirakira
# Processing Record 4 of Set 14 | mecca
# Processing Record 5 of Set 14 | moose factory
# Processing Record 6 of Set 14 | sinjar
# Processing Record 7 of Set 14 | petropavl
# Processing Record 8 of Set 14 | lufilufi
# Processing Record 9 of Set 14 | tamandare
# Processing Record 10 of Set 14 | yola
# Processing Record 11 of Set 14 | berlevag
# Processing Record 12 of Set 14 | malanje
# Processing Record 13 of Set 14 | quesnel
# Processing Record 14 of Set 14 | matara
# Processing Record 15 of Set 14 | nha trang
# Processing Record 16 of Set 14 | virginia beach
# Processing Record 17 of Set 14 | ngukurr
# City not found. Skipping...
# Processing Record 18 of Set 14 | lagdo
# Processing Record 19 of Set 14 | las vegas
# Processing Record 20 of Set 14 | ibotirama
# Processing Record 21 of Set 14 | sydney mines
# Processing Record 22 of Set 14 | casper
# Processing Record 23 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 24 of Set 14 | mingaora
# Processing Record 25 of Set 14 | inirida
# Processing Record 26 of Set 14 | mocambique
# City not found. Skipping...
# Processing Record 27 of Set 14 | afikpo
# Processing Record 28 of Set 14 | juneau
# Processing Record 29 of Set 14 | muros
# Processing Record 30 of Set 14 | chalmette
# Processing Record 31 of Set 14 | higuey
# City not found. Skipping...
# Processing Record 32 of Set 14 | nacala
# Processing Record 33 of Set 14 | anderson
# Processing Record 34 of Set 14 | alagir
# Processing Record 35 of Set 14 | kavaratti
# Processing Record 36 of Set 14 | mantua
# Processing Record 37 of Set 14 | kaohsiung
# Processing Record 38 of Set 14 | daru
# Processing Record 39 of Set 14 | mocuba
# Processing Record 40 of Set 14 | kisangani
# Processing Record 41 of Set 14 | itupiranga
# Processing Record 42 of Set 14 | cayenne
# Processing Record 43 of Set 14 | ngunguru
# Processing Record 44 of Set 14 | bowen
# Processing Record 45 of Set 14 | gwadar
# Processing Record 46 of Set 14 | portland
# Processing Record 47 of Set 14 | ostrovnoy
# Processing Record 48 of Set 14 | la union
# Processing Record 49 of Set 14 | diego de almagro
# Processing Record 50 of Set 14 | pochutla
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
print(len(city_data))
# Out:
# 649

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City      Lat       Lng Current Description  Max Temp  Humidity  \
# 0      Rikitea -23.1203 -134.9692           clear sky     74.10        76
# 1        Kapaa  22.0752 -159.3190       broken clouds     84.18        72
# 2  Tuktoyaktuk  69.4541 -133.0374     overcast clouds     45.23        92
# 3   Nouadhibou  20.9310  -17.0347    scattered clouds     67.30        95
# 4    Busselton -33.6500  115.3333          light rain     59.59        81
# 5  Deputatskiy  69.3000  139.9000     overcast clouds     33.01        99
# 6     Luderitz -26.6481   15.1594           clear sky     57.52        67
# 7       Castro -24.7911  -50.0119           clear sky     61.57        85
# 8    Anchorage  61.2181 -149.9003       moderate rain     53.94        93
# 9       Tiarei -17.5333 -149.3333           clear sky     76.46        67
#
#    Cloudiness  Wind Speed Country                 Date
# 0           2        9.22      PF  2022-07-19 22:00:19
# 1          64        7.00      US  2022-07-19 21:57:32
# 2         100       10.58      CA  2022-07-19 22:00:20
# 3          26       16.53      MR  2022-07-19 22:00:21
# 4         100       12.39      AU  2022-07-19 21:57:31
# 5         100        4.16      RU  2022-07-19 22:00:21
# 6           1       17.96      NA  2022-07-19 21:59:41
# 7           2        0.47      BR  2022-07-19 22:00:22
# 8         100        8.99      US  2022-07-19 22:00:00
# 9           4        2.64      PF  2022-07-19 22:00:23

# %%
city_data_df = city_data_df[["City", "Country", "Date", "Current Description", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]]

city_data_df.head()
# Out:
#           City Country                 Date Current Description      Lat  \
# 0      Rikitea      PF  2022-07-19 22:00:19           clear sky -23.1203
# 1        Kapaa      US  2022-07-19 21:57:32       broken clouds  22.0752
# 2  Tuktoyaktuk      CA  2022-07-19 22:00:20     overcast clouds  69.4541
# 3   Nouadhibou      MR  2022-07-19 22:00:21    scattered clouds  20.9310
# 4    Busselton      AU  2022-07-19 21:57:31          light rain -33.6500
#
#         Lng  Max Temp  Humidity  Cloudiness  Wind Speed
# 0 -134.9692     74.10        76           2        9.22
# 1 -159.3190     84.18        72          64        7.00
# 2 -133.0374     45.23        92         100       10.58
# 3  -17.0347     67.30        95          26       16.53
# 4  115.3333     59.59        81         100       12.39

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
